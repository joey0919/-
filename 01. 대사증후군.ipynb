# %% [markdown]
# # 01. 대사증후군

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
result_list = list()

# %% [markdown]
# ## 2011년도 대사증후군 데이터

# %%
year = '2011'

df = pd.read_csv(f'NHIS{year}.CSV', encoding='CP949')
df.head(100)

# 1. 복부 둘레 증가
filt1 = ((df['허리둘레'] >= 101) & (df['성별코드'] == 1)) | ((df['허리둘레'] >= 88) & (df['성별코드'] == 2))
df.loc[filt1]

# 2. 중성 지방 수치 상승
filt2 = (df['트리글리세라이드'] >= 150)
df.loc[filt2]

# 3. HDL-콜레스테롤 감소
filt3 = ((df['HDL콜레스테롤'] < 40) & (df['성별코드'] == 1) | (df['HDL콜레스테롤'] < 50) & (df['성별코드'] == 2))
df.loc[filt3]

# 4. 혈당 상승
filt4 = (df['식전혈당(공복혈당)'] >= 100)
df.loc[filt4]

# 5. 혈압 상승
filt5 = ((df['수축기혈압'] >= 130) | (df['이완기혈압'] >= 85))
df.loc[filt5]

# 3개 이상의 조건 만족
filt_combined = (filt1.astype(int) + filt2.astype(int) + filt3.astype(int) + filt4.astype(int) + filt5.astype(int)) >= 3

# 결과
result_df = df.loc[filt_combined]
row_count = result_df.shape[0]
result_list.append(row_count)

result_df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2440\2224680140.py:3: DtypeWarning: Columns (31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'NHIS{year}.CSV', encoding='CP949')
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 221     2011    86261     2            1    28        155          50    66
# 337     2011   919976     2            1    11        155          55    70
# 353     2011   494059     2            1    31        155          60    78
# 386     2011   241261     2            1    42        155          70    83
# 387     2011   293893     2            1    30        155          70    90
# ...      ...      ...   ...          ...   ...        ...         ...   ...
# 999981  2011   394477     2           14    44        140          35    70
# 999982  2011   561236     2           14    11        140          35    60
# 999984  2011   164194     2           14    46        140          40    60
# 999986  2011   266398     2           14    26        145          40    79
# 999992  2011   279066     2           14    47        150          50    89
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  \
# 221       1.0    1.2  ...     11   1.0     N          N      NaN    NaN
# 337       0.9    0.8  ...     11   3.0     N          Y        Y      N
# 353       0.7    0.6  ...     17   1.0     N          N      NaN    NaN
# 386       1.2    1.2  ...     22   1.0     Y          Y        Y      N
# 387       0.4    0.3  ...     23   1.0     Y          Y      NaN      N
# ...       ...    ...  ...    ...   ...   ...        ...      ...    ...
# 999981    0.1    0.2  ...     23   1.0     N          N      NaN    NaN
# 999982    0.2    0.2  ...     23   1.0     N          N      NaN    NaN
# 999984    0.1    0.1  ...     26   1.0     N          N      NaN    NaN
# 999986    0.2    0.1  ...     12   1.0     N          N      NaN    NaN
# 999992    0.4    0.4  ...     34   1.0     N          N      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상   치석     데이터공개일자
# 221         NaN           NaN  NaN  2015-12-20
# 337           N             N    Y  2015-12-20
# 353         NaN           NaN  NaN  2015-12-20
# 386           N             N    Y  2015-12-20
# 387           Y             N    Y  2015-12-20
# ...         ...           ...  ...         ...
# 999981      NaN           NaN  NaN  2015-12-20
# 999982      NaN           NaN  NaN  2015-12-20
# 999984      NaN           NaN  NaN  2015-12-20
# 999986      NaN           NaN  NaN  2015-12-20
# 999992      NaN           NaN  NaN  2015-12-20
#
# [140986 rows x 34 columns]

# %% [markdown]
# ## 2012년도 대사증후군 데이터

# %%
year = '2012'

df = pd.read_csv(f'NHIS{year}.CSV', encoding='CP949')
df.head(100)

# 1. 복부 둘레 증가
filt1 = ((df['허리둘레'] >= 101) & (df['성별코드'] == 1)) | ((df['허리둘레'] >= 88) & (df['성별코드'] == 2))
df.loc[filt1]

# 2. 중성 지방 수치 상승
filt2 = (df['트리글리세라이드'] >= 150)
df.loc[filt2]

# 3. HDL-콜레스테롤 감소
filt3 = ((df['HDL콜레스테롤'] < 40) & (df['성별코드'] == 1) | (df['HDL콜레스테롤'] < 50) & (df['성별코드'] == 2))
df.loc[filt3]

# 4. 혈당 상승
filt4 = (df['식전혈당(공복혈당)'] >= 100)
df.loc[filt4]

# 5. 혈압 상승
filt5 = ((df['수축기혈압'] >= 130) | (df['이완기혈압'] >= 85))
df.loc[filt5]

# 3개 이상의 조건 만족
filt_combined = (filt1.astype(int) + filt2.astype(int) + filt3.astype(int) + filt4.astype(int) + filt5.astype(int)) >= 3

# 결과
result_df = df.loc[filt_combined]
row_count = result_df.shape[0]
result_list.append(row_count)

result_df
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 327     2012   902101     2            1    41        155          55    76
# 374     2012   883987     2            1    41        155          70    80
# 599     2012    38544     1            1    41        160          50    68
# 718     2012   387436     2            1    47        160          60    70
# 865     2012   995794     1            1    41        165          50    72
# ...      ...      ...   ...          ...   ...        ...         ...   ...
# 999983  2012    36863     2           14    11        145          50    88
# 999984  2012   254388     2           14    11        150          45    76
# 999992  2012   865661     2           14    43        140          35    67
# 999993  2012   218995     2           14    30        140          35    82
# 999997  2012   518208     2           14    41        145          40    73
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  \
# 327       0.7    0.8  ...     12   3.0     N          Y        Y      N
# 374       0.7    0.7  ...     65   1.0     Y          Y        Y      N
# 599       0.4    0.4  ...     15   3.0     Y          Y        N      N
# 718       1.5    1.2  ...     29   1.0     Y          Y        Y      N
# 865       1.2    0.9  ...     27   1.0     Y          Y        Y      Y
# ...       ...    ...  ...    ...   ...   ...        ...      ...    ...
# 999983    0.4    0.2  ...     12   1.0     N          N      NaN    NaN
# 999984    0.8    0.8  ...     13   1.0     N          Y        Y      Y
# 999992    0.3    0.2  ...      9   1.0     N          N      NaN    NaN
# 999993    9.9    0.2  ...     15   1.0     N          N      NaN    NaN
# 999997    0.5    0.5  ...     16   1.0     N          N      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상   치석     데이터공개일자
# 327           N             N    Y  2015-12-20
# 374           N             N    Y  2015-12-20
# 599           N             N    N  2015-12-20
# 718           N             N    N  2015-12-20
# 865           N             N    Y  2015-12-20
# ...         ...           ...  ...         ...
# 999983      NaN           NaN  NaN  2015-12-20
# 999984        N             N    Y  2015-12-20
# 999992      NaN           NaN  NaN  2015-12-20
# 999993      NaN           NaN  NaN  2015-12-20
# 999997      NaN           NaN  NaN  2015-12-20
#
# [140962 rows x 34 columns]

# %% [markdown]
# ## 2013년도 대사증후군 데이터

# %%
year = '2013'

df = pd.read_csv(f'NHIS{year}.CSV', encoding='CP949')
df.head(100)

# 1. 복부 둘레 증가
filt1 = ((df['허리둘레'] >= 101) & (df['성별코드'] == 1)) | ((df['허리둘레'] >= 88) & (df['성별코드'] == 2))
df.loc[filt1]

# 2. 중성 지방 수치 상승
filt2 = (df['트리글리세라이드'] >= 150)
df.loc[filt2]

# 3. HDL-콜레스테롤 감소
filt3 = ((df['HDL콜레스테롤'] < 40) & (df['성별코드'] == 1) | (df['HDL콜레스테롤'] < 50) & (df['성별코드'] == 2))
df.loc[filt3]

# 4. 혈당 상승
filt4 = (df['식전혈당(공복혈당)'] >= 100)
df.loc[filt4]

# 5. 혈압 상승
filt5 = ((df['수축기혈압'] >= 130) | (df['이완기혈압'] >= 85))
df.loc[filt5]

# 3개 이상의 조건 만족
filt_combined = (filt1.astype(int) + filt2.astype(int) + filt3.astype(int) + filt4.astype(int) + filt5.astype(int)) >= 3

# 결과
result_df = df.loc[filt_combined]
row_count = result_df.shape[0]
result_list.append(row_count)

result_df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2440\860362758.py:3: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'NHIS{year}.CSV', encoding='CP949')
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 0       2013    24193     2           14    11        145          35    83
# 66      2013    10290     1            1    27        150          50    81
# 93      2013   436989     2            1    41        150          65    79
# 408     2013   230766     2            1    26        155          80    98
# 757     2013   874569     2            1    41        160          60    85
# ...      ...      ...   ...          ...   ...        ...         ...   ...
# 999974  2013   315109     2           14    44        140          40    80
# 999982  2013   532686     2           14    41        145          50    85
# 999987  2013   481860     2           14    46        150          40    72
# 999991  2013   587149     2           14    41        150          50    83
# 999999  2013   487152     2           14    27        145          45    85
#
#         시력(좌)  시력(우)  ...  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  치아마모증유무  \
# 0         0.1    0.1  ...     N          N      NaN    NaN      NaN
# 66        0.8    0.8  ...     N          N      NaN    NaN      NaN
# 93        1.2    1.0  ...     Y          Y        N      N        N
# 408       0.2    0.2  ...     N          N      NaN    NaN      NaN
# 757       1.0    0.9  ...     N          N      NaN    NaN      NaN
# ...       ...    ...  ...   ...        ...      ...    ...      ...
# 999974    0.1    0.1  ...     N          N      NaN    NaN      NaN
# 999982    0.3    0.3  ...     N          N      NaN    NaN      NaN
# 999987    0.5    0.6  ...     N          N      NaN    NaN      NaN
# 999991    0.1    0.1  ...     N          N      NaN    NaN      NaN
# 999999    0.5    0.9  ...     N          N      NaN    NaN      NaN
#
#         제3대구치(사랑니)이상   치석     데이터공개일자  Unnamed: 34  Unnamed: 35
# 0                NaN  NaN  2015-12-20          NaN          NaN
# 66               NaN  NaN  2015-12-20          NaN          NaN
# 93                 N    Y  2015-12-20          NaN          NaN
# 408              NaN  NaN  2015-12-20          NaN          NaN
# 757              NaN  NaN  2015-12-20          NaN          NaN
# ...              ...  ...         ...          ...          ...
# 999974           NaN  NaN  2015-12-20          NaN          NaN
# 999982           NaN  NaN  2015-12-20          NaN          NaN
# 999987           NaN  NaN  2015-12-20          NaN          NaN
# 999991           NaN  NaN  2015-12-20          NaN          NaN
# 999999           NaN  NaN  2015-12-20          NaN          NaN
#
# [145501 rows x 36 columns]

# %% [markdown]
# ## 2014년도 대사증후군 데이터

# %%
year = '2014'

df = pd.read_csv(f'NHIS{year}.CSV', encoding='CP949')
df.head(100)

# 1. 복부 둘레 증가
filt1 = ((df['허리둘레'] >= 101) & (df['성별코드'] == 1)) | ((df['허리둘레'] >= 88) & (df['성별코드'] == 2))
df.loc[filt1]

# 2. 중성 지방 수치 상승
filt2 = (df['트리글리세라이드'] >= 150)
df.loc[filt2]

# 3. HDL-콜레스테롤 감소
filt3 = ((df['HDL콜레스테롤'] < 40) & (df['성별코드'] == 1) | (df['HDL콜레스테롤'] < 50) & (df['성별코드'] == 2))
df.loc[filt3]

# 4. 혈당 상승
filt4 = (df['식전혈당(공복혈당)'] >= 100)
df.loc[filt4]

# 5. 혈압 상승
filt5 = ((df['수축기혈압'] >= 130) | (df['이완기혈압'] >= 85))
df.loc[filt5]

# 3개 이상의 조건 만족
filt_combined = (filt1.astype(int) + filt2.astype(int) + filt3.astype(int) + filt4.astype(int) + filt5.astype(int)) >= 3

# 결과
result_df = df.loc[filt_combined]
row_count = result_df.shape[0]
result_list.append(row_count)

result_df
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 3       2014        4     2           11    41        165          80   104
# 7       2014        8     2           11    41        145          55    93
# 26      2014       27     2           18    11        150          65    95
# 27      2014       28     2           18    41        155          60    86
# 29      2014       30     2           11    26        155          70    84
# ...      ...      ...   ...          ...   ...        ...         ...   ...
# 999970  2014   999971     1           11    43        170          75    85
# 999974  2014   999975     1            8    43        180          70    93
# 999977  2014   999978     1            7    11        170          70    80
# 999984  2014   999985     2           10    36        165          70    82
# 999985  2014   999986     1            8    41        180          80    90
#
#         시력(좌)  시력(우)  ...  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  흡연상태  음주여부  \
# 3         0.8    0.2  ...      0.9          19          14     21   1.0     N
# 7         0.9    0.9  ...      1.2          34          16    175   1.0     Y
# 26        0.4    0.3  ...      0.9          24          13     26   1.0     Y
# 27        0.6    0.6  ...      1.1          18          11     13   1.0     Y
# 29        0.7    0.7  ...      0.9          37          36     23   1.0     Y
# ...       ...    ...  ...      ...         ...         ...    ...   ...   ...
# 999970    0.5    1.0  ...      1.1          19          11     27   3.0     N
# 999974    1.2    0.9  ...      0.9          23          23     90   3.0     Y
# 999977    0.5    0.8  ...      0.8          17          15     17   1.0     Y
# 999984    1.2    0.7  ...      1.0          20          20     16   1.0     Y
# 999985    1.0    0.9  ...      1.1          14          18     53   3.0     Y
#
#         구강검진 수검여부  치아우식증유무  치석유무    데이터 기준일자
# 3               Y        N     Y  2016-12-20
# 7               N      NaN   NaN  2016-12-20
# 26              Y      NaN     N  2016-12-20
# 27              N      NaN   NaN  2016-12-20
# 29              N      NaN   NaN  2016-12-20
# ...           ...      ...   ...         ...
# 999970          N      NaN   NaN  2016-12-20
# 999974          N      NaN   NaN  2016-12-20
# 999977          N      NaN   NaN  2016-12-20
# 999984          N      NaN   NaN  2016-12-20
# 999985          N      NaN   NaN  2016-12-20
#
# [146973 rows x 31 columns]

# %% [markdown]
# ## 2015년도 대사증후군 데이터

# %%
year = '2015'

df = pd.read_csv(f'NHIS{year}.CSV', encoding='CP949')
df.head(100)

# 1. 복부 둘레 증가
filt1 = ((df['허리둘레'] >= 101) & (df['성별코드'] == 1)) | ((df['허리둘레'] >= 88) & (df['성별코드'] == 2))
df.loc[filt1]

# 2. 중성 지방 수치 상승
filt2 = (df['트리글리세라이드'] >= 150)
df.loc[filt2]

# 3. HDL-콜레스테롤 감소
filt3 = ((df['HDL콜레스테롤'] < 40) & (df['성별코드'] == 1) | (df['HDL콜레스테롤'] < 50) & (df['성별코드'] == 2))
df.loc[filt3]

# 4. 혈당 상승
filt4 = (df['식전혈당(공복혈당)'] >= 100)
df.loc[filt4]

# 5. 혈압 상승
filt5 = ((df['수축기혈압'] >= 130) | (df['이완기혈압'] >= 85))
df.loc[filt5]

# 3개 이상의 조건 만족
filt_combined = (filt1.astype(int) + filt2.astype(int) + filt3.astype(int) + filt4.astype(int) + filt5.astype(int)) >= 3

# 결과
result_df = df.loc[filt_combined]
row_count = result_df.shape[0]
result_list.append(row_count)

result_df
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 0       2015        1     2           15    45        155          60    88
# 1       2015        2     2           15    11        155          65    98
# 3       2015        4     1            9    41        175          75    89
# 13      2015       14     1           18    30        160          60    85
# 14      2015       15     2           18    46        150          55    82
# ...      ...      ...   ...          ...   ...        ...         ...   ...
# 999882  2015   999883     1           13    44        165          55    75
# 999883  2015   999884     1            8    41        165          60    74
# 999891  2015   999892     1            7    41        180         105    99
# 999966  2015   999967     1            6    43        180          85    87
# 999984  2015   999985     1            8    47        170          75    90
#
#         시력(좌)  시력(우)  ...  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  흡연상태  음주여부  \
# 0         0.6    0.7  ...      1.1          17          28     23   1.0     Y
# 1         1.2    0.6  ...      1.0          25          30     41   1.0     Y
# 3         0.2    0.2  ...      0.9          28          40     50   1.0     Y
# 13        0.7    0.6  ...      1.1          28          20     43   3.0     Y
# 14        0.8    0.5  ...      0.8          45          37     69   1.0     Y
# ...       ...    ...  ...      ...         ...         ...    ...   ...   ...
# 999882    0.3    0.5  ...      0.8          31          18     59   3.0     N
# 999883    1.2    1.0  ...      0.9          31          41     22   1.0     Y
# 999891    1.2    1.5  ...      1.2          57          55    139   3.0     Y
# 999966    1.5    0.8  ...      1.1          22          24     58   1.0     Y
# 999984    0.8    0.8  ...      0.8          24          52     43   3.0     Y
#
#         구강검진 수검여부  치아우식증유무  치석유무    데이터 기준일자
# 0               N      NaN   NaN  2016-12-20
# 1               Y      NaN     N  2016-12-20
# 3               Y        N   NaN  2016-12-20
# 13              Y      NaN     N  2016-12-20
# 14              N      NaN   NaN  2016-12-20
# ...           ...      ...   ...         ...
# 999882          Y      NaN     Y  2016-12-20
# 999883          N      NaN   NaN  2016-12-20
# 999891          N      NaN   NaN  2016-12-20
# 999966          Y      NaN   NaN  2016-12-20
# 999984          Y      NaN   NaN  2016-12-20
#
# [151517 rows x 31 columns]

# %% [markdown]
# ## 2016년도 대사증후군 데이터

# %%
year = '2016'

df = pd.read_csv(f'NHIS{year}.CSV', encoding='CP949')
df.head(100)

# 1. 복부 둘레 증가
filt1 = ((df['허리둘레'] >= 101) & (df['성별코드'] == 1)) | ((df['허리둘레'] >= 88) & (df['성별코드'] == 2))
df.loc[filt1]

# 2. 중성 지방 수치 상승
filt2 = (df['트리글리세라이드'] >= 150)
df.loc[filt2]

# 3. HDL-콜레스테롤 감소
filt3 = ((df['HDL콜레스테롤'] < 40) & (df['성별코드'] == 1) | (df['HDL콜레스테롤'] < 50) & (df['성별코드'] == 2))
df.loc[filt3]

# 4. 혈당 상승
filt4 = (df['식전혈당(공복혈당)'] >= 100)
df.loc[filt4]

# 5. 혈압 상승
filt5 = ((df['수축기혈압'] >= 130) | (df['이완기혈압'] >= 85))
df.loc[filt5]

# 3개 이상의 조건 만족
filt_combined = (filt1.astype(int) + filt2.astype(int) + filt3.astype(int) + filt4.astype(int) + filt5.astype(int)) >= 3

# 결과
result_df = df.loc[filt_combined]
row_count = result_df.shape[0]
result_list.append(row_count)

result_df
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 1       2016        2     2           11    41      160.0       65.0  85.0
# 7       2016        8     2           16    48      155.0       60.0  81.0
# 24      2016       25     1           13    11      170.0       70.0  92.0
# 26      2016       27     1           16    27      165.0       65.0  95.0
# 30      2016       31     1            9    11      175.0       85.0  97.0
# ...      ...      ...   ...          ...   ...        ...        ...   ...
# 999975  2016   999976     1           13    26      170.0       75.0  85.0
# 999983  2016   999984     1           11    11      175.0       80.0  83.0
# 999988  2016   999989     1            9    45      170.0       80.0  90.0
# 999990  2016   999991     2           11    41      150.0       75.0  99.0
# 999995  2016   999996     1           10    42      170.0       75.0  86.0
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  \
# 1         1.5    1.2  ...   19.0   1.0   NaN          N      NaN    NaN
# 7         0.7    0.5  ...   14.0   1.0   NaN          N      NaN    NaN
# 24        0.9    1.2  ...   61.0   2.0   NaN          N      NaN    NaN
# 26        0.8    0.8  ...   14.0   1.0   NaN          N      NaN    NaN
# 30        1.2    1.2  ...  105.0   2.0   NaN          N      NaN    NaN
# ...       ...    ...  ...    ...   ...   ...        ...      ...    ...
# 999975    1.0    1.2  ...   21.0   1.0   NaN          N      NaN    NaN
# 999983    1.0    1.2  ...   25.0   1.0   NaN          Y      NaN    NaN
# 999988    2.0    1.5  ...   52.0   3.0   NaN          N      NaN    NaN
# 999990    0.5    0.5  ...   31.0   1.0   NaN          N      NaN    NaN
# 999995    0.8    0.8  ...   44.0   3.0   NaN          Y      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상   치석     데이터공개일자
# 1           NaN           NaN  NaN  2017-12-19
# 7           NaN           NaN  NaN  2017-12-19
# 24          NaN           NaN  NaN  2017-12-19
# 26          NaN           NaN  NaN  2017-12-19
# 30          NaN           NaN  NaN  2017-12-19
# ...         ...           ...  ...         ...
# 999975      NaN           NaN  NaN  2017-12-19
# 999983      NaN           NaN    Y  2017-12-19
# 999988      NaN           NaN  NaN  2017-12-19
# 999990      NaN           NaN  NaN  2017-12-19
# 999995      NaN           NaN  NaN  2017-12-19
#
# [155860 rows x 34 columns]

# %% [markdown]
# ## 2017년도 대사증후군 데이터

# %%
year = '2017'

df = pd.read_csv(f'NHIS{year}.CSV', encoding='CP949')
df.head(100)

# 1. 복부 둘레 증가
filt1 = ((df['허리둘레'] >= 101) & (df['성별코드'] == 1)) | ((df['허리둘레'] >= 88) & (df['성별코드'] == 2))
df.loc[filt1]

# 2. 중성 지방 수치 상승
filt2 = (df['트리글리세라이드'] >= 150)
df.loc[filt2]

# 3. HDL-콜레스테롤 감소
filt3 = ((df['HDL콜레스테롤'] < 40) & (df['성별코드'] == 1) | (df['HDL콜레스테롤'] < 50) & (df['성별코드'] == 2))
df.loc[filt3]

# 4. 혈당 상승
filt4 = (df['식전혈당(공복혈당)'] >= 100)
df.loc[filt4]

# 5. 혈압 상승
filt5 = ((df['수축기혈압'] >= 130) | (df['이완기혈압'] >= 85))
df.loc[filt5]

# 3개 이상의 조건 만족
filt_combined = (filt1.astype(int) + filt2.astype(int) + filt3.astype(int) + filt4.astype(int) + filt5.astype(int)) >= 3

# 결과
result_df = df.loc[filt_combined]
row_count = result_df.shape[0]
result_list.append(row_count)

result_df
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg단위)  허리둘레  \
# 12      2017       13     2           12    41        150         55  72.3
# 19      2017       20     1           13    44        165         60  85.0
# 22      2017       23     2           10    45        155         50  62.0
# 37      2017       38     2           13    42        150         50  77.0
# 41      2017       42     2            9    41        160         55  69.0
# ...      ...      ...   ...          ...   ...        ...        ...   ...
# 999969  2017   999970     2           12    47        160         70  91.2
# 999973  2017   999974     2           13    11        155         55  70.0
# 999974  2017   999975     2           13    11        155         50  69.5
# 999977  2017   999978     1            8    27        175         85  96.0
# 999999  2017  1000000     1           11    41        160         70  90.5
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진수검여부  치아우식증유무  결손치유무  \
# 12        1.2    0.9  ...   31.0   1.0     N         Y      NaN    NaN
# 19        0.3    0.7  ...   48.0   3.0     Y         N      NaN    NaN
# 22        0.5    0.7  ...   60.0   1.0     N         N      NaN    NaN
# 37        1.2    1.2  ...   48.0   1.0     N         N      NaN    NaN
# 41        0.9    1.2  ...   23.0   1.0     N         N      NaN    NaN
# ...       ...    ...  ...    ...   ...   ...       ...      ...    ...
# 999969    1.2    1.0  ...   25.0   1.0     N         N      NaN    NaN
# 999973    1.2    1.0  ...   19.0   1.0     N         N      NaN    NaN
# 999974    0.9    0.9  ...   25.0   1.0     N         N      NaN    NaN
# 999977    1.0    1.2  ...   37.0   1.0     Y         Y      NaN    NaN
# 999999    1.0    1.5  ...   36.0   3.0     Y         N      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상   치석     데이터공개일자
# 12          NaN           NaN    Y  2018-11-26
# 19          NaN           NaN  NaN  2018-11-26
# 22          NaN           NaN  NaN  2018-11-26
# 37          NaN           NaN  NaN  2018-11-26
# 41          NaN           NaN  NaN  2018-11-26
# ...         ...           ...  ...         ...
# 999969      NaN           NaN  NaN  2018-11-26
# 999973      NaN           NaN  NaN  2018-11-26
# 999974      NaN           NaN  NaN  2018-11-26
# 999977      NaN           NaN    Y  2018-11-26
# 999999      NaN           NaN  NaN  2018-11-26
#
# [156615 rows x 34 columns]

# %% [markdown]
# ## 결과: 대사증후군 증가율

# %%
year_list = [2011, 2012, 2013, 2014, 2015, 2016, 2017]
result_list

plt.figure(figsize=(10, 8))
plt.plot(year_list, result_list, marker='o')

for idx, txt in enumerate(result_list):
    plt.text(year_list[idx], result_list[idx] + 500, txt, ha='center')

plt.show()

# %%
result_data = {
    '2011': result_list[0],
    '2012': result_list[1],
    '2013': result_list[2],
    '2014': result_list[3],
    '2015': result_list[4],
    '2016': result_list[5],
    '2017': result_list[6]
}

result_df = pd.Series(result_csv)

result_df.to_csv('대사증후군.csv', encoding='UTF-8-sig')
result_df
# Out:
# 2011    140986
# 2012    140962
# 2013    145501
# 2014    146973
# 2015    151517
# 2016    155860
# 2017    156615
# dtype: int64
